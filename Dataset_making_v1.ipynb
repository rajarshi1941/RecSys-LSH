# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link = '/content/drive/My Drive/LSH REC/2019-Nov.csv'

# %%
df = pd.read_csv(link)

# %%
df.head(10)
# Out:
#                 event_time event_type  product_id   category_id  \
# 0  2019-11-01 00:00:00 UTC       view   1003461.0  2.053014e+18
# 1  2019-11-01 00:00:00 UTC       view   5000088.0  2.053014e+18
# 2  2019-11-01 00:00:01 UTC       view  17302664.0  2.053014e+18
# 3  2019-11-01 00:00:01 UTC       view   3601530.0  2.053014e+18
# 4  2019-11-01 00:00:01 UTC       view   1004775.0  2.053014e+18
# 5  2019-11-01 00:00:01 UTC       view   1306894.0  2.053014e+18
# 6  2019-11-01 00:00:01 UTC       view   1306421.0  2.053014e+18
# 7  2019-11-01 00:00:02 UTC       view  15900065.0  2.053014e+18
# 8  2019-11-01 00:00:02 UTC       view  12708937.0  2.053014e+18
# 9  2019-11-01 00:00:02 UTC       view   1004258.0  2.053014e+18
#
#                category_code     brand   price      user_id  \
# 0     electronics.smartphone    xiaomi  489.07  520088904.0
# 1  appliances.sewing_machine    janome  293.65  530496790.0
# 2                        NaN     creed   28.31  561587266.0
# ...

# %%
df.nunique()
# Out:
# event_time        56521
# event_type            3
# product_id        67330
# category_id         605
# category_code       123
# brand              2668
# price             19140
# user_id          176569
# user_session     247170
# dtype: int64

# %%
df.isna().sum()
# Out:
# event_time         1340
# event_type         1340
# product_id         1340
# category_id        1340
# category_code    332997
# brand            155449
# price              1340
# user_id            1340
# user_session       1340
# dtype: int64

# %%
df_n = df.dropna()

# %%
df_n.nunique()
# Out:
# event_time        55826
# event_type            3
# product_id        27470
# category_id         234
# category_code       122
# brand              1372
# price             11350
# user_id          126294
# user_session     170818
# dtype: int64

# %%
df_n = df_n.drop_duplicates()

# %%
df_n = df_n.drop('event_time', axis = 1)

# %%
df_n = df_n.drop('user_session', axis = 1)

# %%
df_n.columns
# Out:
# Index(['event_type', 'product_id', 'category_id', 'category_code', 'brand',
#        'price', 'user_id'],
#       dtype='object')

# %%
df_n = pd.get_dummies(df_n, columns = ['category_code'], dtype=int)

# %%
df_n.head(100)
# Out:
#     event_type  product_id   category_id    brand   price      user_id  \
# 0         view   1003461.0  2.053014e+18   xiaomi  489.07  520088904.0
# 1         view   5000088.0  2.053014e+18   janome  293.65  530496790.0
# 3         view   3601530.0  2.053014e+18       lg  712.87  518085591.0
# 4         view   1004775.0  2.053014e+18   xiaomi  183.27  558856683.0
# 5         view   1306894.0  2.053014e+18       hp  360.09  520772685.0
# ..         ...         ...           ...      ...     ...          ...
# 190       view  42900023.0  2.098563e+18  stanley   29.86  512651494.0
# 192       view   1306895.0  2.053014e+18       hp  411.34  520772685.0
# 194       view  21400135.0  2.053014e+18    casio  165.26  565921426.0
# 197       view  57300036.0  2.173217e+18   jordan  102.71  545220871.0
# 198       view  40900007.0  2.127425e+18    fubag   24.71  513998949.0
#
#      category_code_accessories.bag  category_code_accessories.umbrella  \
# ...

# %%
df_n = pd.get_dummies(df_n, columns = ['brand'], dtype=int)

# %%
df_n.shape
# Out:
# (652020, 1499)

# %%
df_n.head(100)
# Out:
#     event_type  product_id   category_id   price      user_id  \
# 0         view   1003461.0  2.053014e+18  489.07  520088904.0
# 1         view   5000088.0  2.053014e+18  293.65  530496790.0
# 3         view   3601530.0  2.053014e+18  712.87  518085591.0
# 4         view   1004775.0  2.053014e+18  183.27  558856683.0
# 5         view   1306894.0  2.053014e+18  360.09  520772685.0
# ..         ...         ...           ...     ...          ...
# 190       view  42900023.0  2.098563e+18   29.86  512651494.0
# 192       view   1306895.0  2.053014e+18  411.34  520772685.0
# 194       view  21400135.0  2.053014e+18  165.26  565921426.0
# 197       view  57300036.0  2.173217e+18  102.71  545220871.0
# 198       view  40900007.0  2.127425e+18   24.71  513998949.0
#
#      category_code_accessories.bag  category_code_accessories.umbrella  \
# 0                                0                                   0
# 1                                0                                   0
# ...
